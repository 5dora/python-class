# %% [markdown]
# 들어가기 전에) 인구데이터 용량이 크므로 **주피터 노트북**에서 진행해주세요
#
# ## 12.2 지도에 프로젝트 결과 표시하기
# #### 12.2.1  목표 수립하기
# #### 12.2.2  프로그램으로 구현하기

# %%
import csv

# 인구 데이터 읽어와서 리스트로 저장하기
f1 = open('LOCAL_PEOPLE_DONG_201912.csv', encoding='utf8')    
data = csv.reader(f1)
next(data)
data = list(data)

print(len(data))


# 행정동코드 데이터 불러와서 리스트로 저장하기
f2 = open('dong_code.csv', encoding='utf8')
code_data = csv.reader(f2)
next(code_data)
next(code_data)
code_data = list(code_data)

print(len(code_data))


# 위치 데이터 불러와서 리스트로 저장하기
f3 = open('dong_location.csv')
location_data = csv.reader(f3)
next(location_data)
location_data = list(location_data)

print(len(location_data))
# Out:
# 71232
# 424
# 438

# %%
# 인구데이터의 데이터타입 변경하기 
for row in data : 
    for i in range(1, 32) : 
        if i <= 2 : 
            row[i] = int(row[i])
        else : 
            row[i] = float(row[i])

print('인구데이터의 데이터타입 변경', type(row[0]), type(row[1]))


# 행정동코드 데이터의 데이터 타입 변환하기
for row in code_data :
    row[0], row[1] = int(row[0]), int(row[1]) # 7자리 행정동코드, 8자리 행정동코드

print('행정동코드 데이터의 데이터 타입', row)



# 위치 정보 데이터의 데이터 타입 변환하기
for row in location_data :
    row[2], row[-2], row[-1] = int(row[2]), float(row[-2]), float(row[-1])

print('위치 정보 데이터의 데이터 타입', row)
# Out:
# 인구데이터의 데이터타입 변경 <class 'str'> <class 'int'>
# 행정동코드 데이터의 데이터 타입 [1125074, 11740685, '서울', '강동구', '길동']
# 위치 정보 데이터의 데이터 타입 ['438', '2008', 1114071, '연남동', '47.055426', '48.724297', 126.9224741, 37.5624936]

# %%
# 2. 행정동별 인구수를 저장하는 빈 딕셔너리를 만들고 행정동별 총생활인구를 딕셔너리에 저장하기
dong_population = {}

for row in data: 
    dong_code, p = row[2], row[3]
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
print(dong_population)
# Out:
# {11215710: 7415769.416499997, 11680545: 8164680.967099996, 11680610: 8959419.755499998, 11680655: 4828701.040999999, 11710570: 6561164.129399999, 11710531: 2103547.6316000014, 11710561: 2913174.9771000003, 11200535: 3941039.3990000007, 11710690: 3705138.6398999984, 11710641: 3823148.3814, 11740560: 1978341.6221000007, 11620630: 4263738.359700001, 11740580: 2676770.9962999993, 11620775: 3233843.915699998, 11590680: 4742985.799199999, 11650600: 3387216.912600001, 11740700: 5168947.2334, 11170520: 2056919.201300001, 11680521: 7923460.624099997, 11710566: 3627430.840000001, 11680630: 5703460.843199999, 11140570: 2743822.4970000004, 11710532: 2157272.3617, 11710580: 4904999.060800001, 11710642: 8211650.0002000015, 11740610: 7964485.628599999, 11710632: 5083018.323600001, 11710631: 5056888.1863, 11650540: 6497341.8375, 11200690: 6276365.287399996, 11215740: 2768716.1422999995, 11740660: 4534746.617700002, 11215840: 4460143.578599998, 11305660: 4957
# 3. 인구수를 기준으로 내림차순 정렬하고, 앞에서 10개 항목만 별도로 저장하기
import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
print('top10', top10)


top10_code8 = [t[0] for t in top10]
print('top10_code8', top10_code8)
# Out:
# top10 [(11680640, 19089959.907399993), (11560540, 16338121.608699998), (11440660, 13394615.999400008), (11110615, 11925921.1979), (11650530, 11632338.719599992), (11410585, 11267691.1475), (11380690, 10631451.095999997), (11545510, 9989602.009300007), (11680650, 9471823.380199995), (11680610, 8959419.755499998)]
# top10_code8 [11680640, 11560540, 11440660, 11110615, 11650530, 11410585, 11380690, 11545510, 11680650, 11680610]

# %%
top10_name = [0 for i in range(10)]
top10_lat  = [0 for i in range(10)]
top10_long = [0 for i in range(10)]

# 4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code8)) : 
    for row in code_data : 
        if row[1] == top10_code8[i] :  
            # 행정동명 리스트에 저장하기 
            top10_name[i] = row[-1]
            
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print('행정동명에 해당하는 위도와 경도')
print(top10_lat)
print(top10_long)
# 개수도 확인해야해
# Out:
# 행정동명에 해당하는 위도와 경도
# [37.4999211, 0, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 0, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]

# %%
# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print('행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기')
print(top10_lat)
print(top10_long)
# Out:
# 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
# [37.4999211, 37.5286662, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 126.9290731, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]

# %%
# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12)
for i in range(10): 
    folium.Marker(
        [top10_lat[i], top10_long[i]], tooltip=top10_name[i],
        icon=folium.Icon(color='red', icon='star')
        ).add_to(map_top10)

map_top10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a396e682580e1d8b014149ffb55a1195 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a396e682580e1d8b014149ffb55a1195&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a396e682580e1d8b014149ffb55a1195 = L.map(
#                 &quot;map_a396e682580e1d8b014149ffb55a1195&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1927d00c6d220d3f402eff2fb8277c3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var marker_57dcc7915bbaacd75ff2e469f21fe620 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var icon_63c92b3a4831c2d44cdb240e82d0b450 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57dcc7915bbaacd75ff2e469f21fe620.setIcon(icon_63c92b3a4831c2d44cdb240e82d0b450);
#
#
#             marker_57dcc7915bbaacd75ff2e469f21fe620.bindTooltip(
#                 `&lt;div&gt;
#                      1. 1. 역삼1동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_404bea640174d6eb7b02de08a16b3a72 = L.marker(
#                 [37.5286662, 126.9290731],
#                 {}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var icon_e7e49194eff0aa35b4fe13cc0baa9696 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_404bea640174d6eb7b02de08a16b3a72.setIcon(icon_e7e49194eff0aa35b4fe13cc0baa9696);
#
#
#             marker_404bea640174d6eb7b02de08a16b3a72.bindTooltip(
#                 `&lt;div&gt;
#                      2. 2. 여의동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b5c741dd42a05294f1aebfb25ec6c3d7 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var icon_65f33086fed10de65aad72f5c51d3ab8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b5c741dd42a05294f1aebfb25ec6c3d7.setIcon(icon_65f33086fed10de65aad72f5c51d3ab8);
#
#
#             marker_b5c741dd42a05294f1aebfb25ec6c3d7.bindTooltip(
#                 `&lt;div&gt;
#                      3. 3. 서교동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a7c3956ae1a2bccde9fc13bf33d3a75 = L.marker(
#                 [37.5777701, 126.9892737],
#                 {}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var icon_4b6b87940c7bf9846843a75bbf44e694 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a7c3956ae1a2bccde9fc13bf33d3a75.setIcon(icon_4b6b87940c7bf9846843a75bbf44e694);
#
#
#             marker_8a7c3956ae1a2bccde9fc13bf33d3a75.bindTooltip(
#                 `&lt;div&gt;
#                      4. 4. 종로1.2.3.4가동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3c7a8301b5270c9686f8c40a8280ae4e = L.marker(
#                 [37.4856591, 127.0097616],
#                 {}
#             ).addTo(map_a396e682580e1d8b014149ffb55a1195);
#
#
#             var icon_fd3b3effd271886cf1d8b536dd89d956 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c7a8301b5270c9686f8c40a8280ae4e.setIcon(

# %% [markdown]
# #### 12.2.4  추가 분석 : 남성이 많은 지역과 여성이 많은 지역 비교하기

# %%
import csv

# 인구 데이터 읽어와서 리스트로 저장하기
f1 = open('LOCAL_PEOPLE_DONG_201912.csv', encoding='utf8')    
data = csv.reader(f1)
next(data)
data = list(data)

# 행정동코드 데이터 불러와서 리스트로 저장하기
f2 = open('dong_code.csv', encoding='utf8')
code_data = csv.reader(f2)
next(code_data)
next(code_data)
code_data = list(code_data)

# 위치 데이터 불러와서 리스트로 저장하기
f3 = open('dong_location.csv')
location_data = csv.reader(f3)
next(location_data)
location_data = list(location_data)

# %%
# 인구데이터의 데이터타입 변경하기 
for row in data : 
    for i in range(1, 32) : 
        if i <= 2 : 
            row[i] = int(row[i])
        else : 
            row[i] = float(row[i])
            
# 행정동코드 데이터의 데이터 타입 변환하기
for row in code_data :
    row[0], row[1] = int(row[0]), int(row[1]) # 7자리 행정동코드, 8자리 행정동코드

# 위치 정보 데이터의 데이터 타입 변환하기
for row in location_data :
    row[2], row[-2], row[-1] = int(row[2]), float(row[-2]), float(row[-1])

# %%
# 2. 인구 데이터를 읽으며 행정동별 남성 인구수를 저장하는 딕셔너리 완성하기
dong_population = {}

for row in data: 
    # 남성 인구수를 저장하는 변수 p
    dong_code, p = row[2], sum(row[4:18])
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
print(dong_population)
# Out:
# {11215710: 3565142.1284, 11680545: 3686575.8281999975, 11680610: 4593560.314299994, 11680655: 2263327.988, 11710570: 3024619.480299999, 11710531: 1013602.5948999996, 11710561: 1360954.5850999993, 11200535: 1818260.3722999985, 11710690: 1679129.0206000006, 11710641: 1817768.634399999, 11740560: 982007.7637999997, 11620630: 2064953.5107999993, 11740580: 1242821.6660000002, 11620775: 1517228.2631999997, 11590680: 2168451.783800001, 11650600: 1548459.8393000003, 11740700: 2454602.1544000003, 11170520: 998278.3943999995, 11680521: 3880648.0086000026, 11710566: 1686986.8351000005, 11680630: 2695652.446300001, 11140570: 1492571.5226999996, 11710532: 1008238.2982999994, 11710580: 2185437.6525999997, 11710642: 4310919.577699999, 11740610: 3715728.0067000003, 11710632: 2342472.9804999996, 11710631: 2480512.8583000004, 11650540: 3064119.4126999993, 11200690: 3272251.4747, 11215740: 1315572.3026999994, 11740660: 2192903.1867000004, 11215840: 2080190.7824999988, 11305660: 2193693.3588999985, 11110580: 587630.0915000003, 11110650: 2751660.922500002, 11170560: 1684303.255, 11230710: 1920995.579, 11380600: 1857070.4337, 11740530: 1915570.254900001, 11170650: 1077911.8790999998, 11110680: 787243.3211000001, 11140590: 2078629.6478000002, 11110515: 1362787.8328000002, 11110600: 798767.5794000002, 11500535: 2491120.827900001, 11230660: 2099372.8278, 11110690: 313939.19480000006, 11710680: 3432195.274000001, 11170530: 1599914.9410000008, 11710650: 2926696.9382999996, 11260520: 1891371.5547999998, 11470611: 1486129.0336000002, 11290760: 1253046.8536999999, 11350570: 1745103.8832000005, 11500560: 1362990.3153999997, 11170510: 1192877.1639999994, 11740550: 1289344.9547000004, 11650570: 1382520.5212000003, 11470510: 3766679.6034999997, 11230705: 1650881.7536999993, 11500611: 2969176.820600001, 11500630: 2804425.9931999985, 11560535: 3914773.5933999987, 11170625: 4193588.713100001, 11440690: 1344900.6486000007, 11545670: 2493057.9857, 11650550: 829675.1562, 11680730: 1518291.2
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)
# Out:
# [37.4999211, 0, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 0, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]

# %%
# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
                
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)
# Out:
# [37.4999211, 37.5286662, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 126.9290731, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]

# %%
# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12) 
for i in range(10):
    # 1~5위 지역은 진한 파란색, 6~7위 지역은 연한 파란색으로 표시하기
    if i < 5: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='darkblue', icon='male', prefix='fa')
        ).add_to(map_top10)
    else: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='lightblue', icon='male', prefix='fa') 
        ).add_to(map_top10)

map_top10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bb223326b7ab0b7c0c68ae21f6beb20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bb223326b7ab0b7c0c68ae21f6beb20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bb223326b7ab0b7c0c68ae21f6beb20 = L.map(
#                 &quot;map_7bb223326b7ab0b7c0c68ae21f6beb20&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb3eab1290592141c83b32fe67634b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var marker_126e3bc93f02db749c01735f862cb76f = L.marker(
#                 [37.4999211, 127.0367584],
#                 {}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var icon_93a039fe52a437640f6b3e11097e4d3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_126e3bc93f02db749c01735f862cb76f.setIcon(icon_93a039fe52a437640f6b3e11097e4d3a);
#
#
#             marker_126e3bc93f02db749c01735f862cb76f.bindTooltip(
#                 `&lt;div&gt;
#                      1. 역삼1동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f8a440275cce2e17f0bccf274f42ccd6 = L.marker(
#                 [37.5286662, 126.9290731],
#                 {}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var icon_e733f85f96bc77da67344109b6c6fafd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f8a440275cce2e17f0bccf274f42ccd6.setIcon(icon_e733f85f96bc77da67344109b6c6fafd);
#
#
#             marker_f8a440275cce2e17f0bccf274f42ccd6.bindTooltip(
#                 `&lt;div&gt;
#                      2. 여의동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b834c85d757f30a5362df02c6bda2dfe = L.marker(
#                 [37.5550337, 126.9228533],
#                 {}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var icon_140b6fc66045ac14fc95fa578337b775 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b834c85d757f30a5362df02c6bda2dfe.setIcon(icon_140b6fc66045ac14fc95fa578337b775);
#
#
#             marker_b834c85d757f30a5362df02c6bda2dfe.bindTooltip(
#                 `&lt;div&gt;
#                      3. 서교동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b6e6eda8c7608b068df44a2b05c72cc7 = L.marker(
#                 [37.5777701, 126.9892737],
#                 {}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var icon_5184a28ac2bdf5ff534d83246ba5a913 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b6e6eda8c7608b068df44a2b05c72cc7.setIcon(icon_5184a28ac2bdf5ff534d83246ba5a913);
#
#
#             marker_b6e6eda8c7608b068df44a2b05c72cc7.bindTooltip(
#                 `&lt;div&gt;
#                      4. 종로1.2.3.4가동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_80f9e975524cd9fc19818d013c16a9f2 = L.marker(
#                 [37.4856591, 127.0097616],
#                 {}
#             ).addTo(map_7bb223326b7ab0b7c0c68ae21f6beb20);
#
#
#             var icon_033687f58d35c0929b449e4b659f02b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_80f9e975524cd9fc19818d013c16a9f2.setIcon(icon_033687f58d35c0929

# %%
# 2. 인구 데이터를 읽으며 행정동별 여성 인구수를 저장하는 딕셔너리 완성하기
dong_population = {}

for row in data: 
    # 여성 인구수를 저장하는 변수 p
    dong_code, p = row[2], sum(row[18:32])
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
print(dong_population)
# Out:
# {11215710: 3850627.2926000003, 11680545: 4478105.151699999, 11680610: 4365859.441800001, 11680655: 2565373.059999999, 11710570: 3536544.646, 11710531: 1089945.0534999997, 11710561: 1552220.3847999999, 11200535: 2122779.0379999997, 11710690: 2026009.6387999996, 11710641: 2005379.7525999998, 11740560: 996333.8456, 11620630: 2198784.8454, 11740580: 1433949.3179000001, 11620775: 1716615.6460000002, 11590680: 2574534.0160999983, 11650600: 1838757.069400001, 11740700: 2714345.0698000016, 11170520: 1058640.8032000002, 11680521: 4042812.611400002, 11710566: 1940443.9893000005, 11680630: 3007808.3875000007, 11140570: 1251250.9698000005, 11710532: 1149034.0573000002, 11710580: 2719561.428299999, 11710642: 3900730.4245999996, 11740610: 4248757.621400001, 11710632: 2740545.342900002, 11710631: 2576375.3305999967, 11650540: 3433222.4028999982, 11200690: 3004113.830200002, 11215740: 1453143.8304999995, 11740660: 
# %%
# 3. 인구수를 기준으로 내림차순 정렬하고, 앞에서 10개 항목만 별도로 저장하기
import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
print(top10)

top10_code8 = [t[0] for t in top10]
print(top10_code8)
# Out:
# [(11680640, 9190752.430500004), (11560540, 7445531.381299995), (11440660, 7331950.408899998), (11410585, 6735930.968099999), (11380690, 5819385.798300002), (11650530, 5666224.519300001), (11110615, 5216787.786400003), (11680650, 4943801.6795999985), (11740685, 4701770.698599997), (11590530, 4621726.3814)]
# [11680640, 11560540, 11440660, 11410585, 11380690, 11650530, 11110615, 11680650, 11740685, 11590530]

# %%
top10_name = [0 for i in range(10)]
top10_lat  = [0 for i in range(10)]
top10_long = [0 for i in range(10)]

# 4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code8)) : 
    for row in code_data : 
        if row[1] == top10_code8[i] :  
            # 행정동명 리스트에 저장하기 
            top10_name[i] = row[-1]
            
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)
# Out:
# [37.4999211, 0, 37.5550337, 37.5659638, 37.64193, 37.4856591, 37.5777701, 37.4984733, 37.5398758, 37.4999435]
# [127.0367584, 0, 126.9228533, 126.9384315, 126.9387277, 127.0097616, 126.9892737, 127.0449272, 127.1473638, 126.9543551]

# %%
# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
                
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)
# Out:
# [37.4999211, 37.5286662, 37.5550337, 37.5659638, 37.64193, 37.4856591, 37.5777701, 37.4984733, 37.5398758, 37.4999435]
# [127.0367584, 126.9290731, 126.9228533, 126.9384315, 126.9387277, 127.0097616, 126.9892737, 127.0449272, 127.1473638, 126.9543551]

# %%
# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12) 
for i in range(10):
    
    # 1~5위 지역은 진한 파란색, 6~7위 지역은 연한 파란색으로 표시하기
    if i < 5: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='red', icon='female', prefix='fa')
        ).add_to(map_top10)
    else: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='pink', icon='female', prefix='fa') 
        ).add_to(map_top10)

map_top10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bce1385fdbf793babc902175a62e8d80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bce1385fdbf793babc902175a62e8d80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bce1385fdbf793babc902175a62e8d80 = L.map(
#                 &quot;map_bce1385fdbf793babc902175a62e8d80&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc4a0e352b1741faf66f66b6efc850fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var marker_bcb335773d9f80a0cd882521945e96f4 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var icon_34eb819aca8de655bc937969a2793423 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;female&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bcb335773d9f80a0cd882521945e96f4.setIcon(icon_34eb819aca8de655bc937969a2793423);
#
#
#             marker_bcb335773d9f80a0cd882521945e96f4.bindTooltip(
#                 `&lt;div&gt;
#                      1. 역삼1동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ea31e7810126ac199bd9ed9deec60b8 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var icon_905781f4967c5324952c4b3baa6b4871 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;female&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0ea31e7810126ac199bd9ed9deec60b8.setIcon(icon_905781f4967c5324952c4b3baa6b4871);
#
#
#             marker_0ea31e7810126ac199bd9ed9deec60b8.bindTooltip(
#                 `&lt;div&gt;
#                      2. 여의동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea2ee18300bc496c9cc77ade4c0b9615 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var icon_6f63dd44f53e4429290638418a687b8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;female&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ea2ee18300bc496c9cc77ade4c0b9615.setIcon(icon_6f63dd44f53e4429290638418a687b8c);
#
#
#             marker_ea2ee18300bc496c9cc77ade4c0b9615.bindTooltip(
#                 `&lt;div&gt;
#                      3. 서교동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5fbcbd3dd18341c2eee2376efa4a5e12 = L.marker(
#                 [37.5659638, 126.9384315],
#                 {}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var icon_704ff5995ea25e8a2a5ee6db2076f295 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;female&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5fbcbd3dd18341c2eee2376efa4a5e12.setIcon(icon_704ff5995ea25e8a2a5ee6db2076f295);
#
#
#             marker_5fbcbd3dd18341c2eee2376efa4a5e12.bindTooltip(
#                 `&lt;div&gt;
#                      4. 신촌동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c179637a92aad2bdd8b7e14f48008d94 = L.marker(
#                 [37.64193, 126.9387277],
#                 {}
#             ).addTo(map_bce1385fdbf793babc902175a62e8d80);
#
#
#             var icon_eed2b94e93a085d51a8aaa20cd62a648 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;female&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c179637a92aad2bdd8b7e14f48008d94.setIcon(icon_eed2b94e93a085d51a8aaa20cd62a648);

# %% [markdown]
# #### Self Check

# %%
# 1번
import folium

lat1, long1 = 35.15870, 129.16047

# 해운대 해수욕장
map_h = folium.Map([lat1, long1], zoom_start=11)

# 마커 추가하기
folium.Marker([lat1, long1],
              icon=folium.Icon(icon='hand-o-down', prefix='fa')
             ).add_to(map_h)
map_h
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca7e9e1caf0234da6f07865429efa6fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca7e9e1caf0234da6f07865429efa6fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca7e9e1caf0234da6f07865429efa6fd = L.map(
#                 &quot;map_ca7e9e1caf0234da6f07865429efa6fd&quot;,
#                 {
#                     center: [35.1587, 129.16047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70aa39a978d9c84f3563fb61b85144d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca7e9e1caf0234da6f07865429efa6fd);
#
#
#             var marker_770ac0b7e96ee335b677f7a8ca5e67af = L.marker(
#                 [35.1587, 129.16047],
#                 {}
#             ).addTo(map_ca7e9e1caf0234da6f07865429efa6fd);
#
#
#             var icon_b8d927e32c4db27abe21d69a4af26ad6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;hand-o-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_770ac0b7e96ee335b677f7a8ca5e67af.setIcon(icon_b8d927e32c4db27abe21d69a4af26ad6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 2번
import folium

lat = [35.15870, 35.23360, 35.17357]
long = [129.16047, 129.08309, 128.94632]
names = ['해운대 해수욕장', '부산대학교', '김해국제공항'] 
icons = ['hand-o-down', 'university', 'plane']

map_h = folium.Map([lat[0], long[0]], zoom_start=11)

for i in range(len(lat)):
    folium.Marker([lat[i], long[i]], tooltip=names[i],
                  icon=folium.Icon(icon= icons[i], prefix='fa')
                 ).add_to(map_h)
map_h
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24fb7f37d3c41c2abdedf7ec521a2429 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24fb7f37d3c41c2abdedf7ec521a2429&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24fb7f37d3c41c2abdedf7ec521a2429 = L.map(
#                 &quot;map_24fb7f37d3c41c2abdedf7ec521a2429&quot;,
#                 {
#                     center: [35.1587, 129.16047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d823d4900444f3e7fbab165c4459a54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24fb7f37d3c41c2abdedf7ec521a2429);
#
#
#             var marker_d6f1177b1195f91ba6cce5d99d41c279 = L.marker(
#                 [35.1587, 129.16047],
#                 {}
#             ).addTo(map_24fb7f37d3c41c2abdedf7ec521a2429);
#
#
#             var icon_9f8d882e28dd28c574941d304c32f8c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;hand-o-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d6f1177b1195f91ba6cce5d99d41c279.setIcon(icon_9f8d882e28dd28c574941d304c32f8c2);
#
#
#             marker_d6f1177b1195f91ba6cce5d99d41c279.bindTooltip(
#                 `&lt;div&gt;
#                      해운대 해수욕장
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_93567f13f1510ee7cd271e6a2576d49c = L.marker(
#                 [35.2336, 129.08309],
#                 {}
#             ).addTo(map_24fb7f37d3c41c2abdedf7ec521a2429);
#
#
#             var icon_023c60b68b3281d62aa1d9099550f78d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_93567f13f1510ee7cd271e6a2576d49c.setIcon(icon_023c60b68b3281d62aa1d9099550f78d);
#
#
#             marker_93567f13f1510ee7cd271e6a2576d49c.bindTooltip(
#                 `&lt;div&gt;
#                      부산대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_48e7f5982b538975a112150fc1dfc722 = L.marker(
#                 [35.17357, 128.94632],
#                 {}
#             ).addTo(map_24fb7f37d3c41c2abdedf7ec521a2429);
#
#
#             var icon_df2102af29bd263ed306e5d5c2f066d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_48e7f5982b538975a112150fc1dfc722.setIcon(icon_df2102af29bd263ed306e5d5c2f066d7);
#
#
#             marker_48e7f5982b538975a112150fc1dfc722.bindTooltip(
#                 `&lt;div&gt;
#                      김해국제공항
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
